# %% [markdown]
# <div style="
#     background-color: #7BAFD4;
#     border-radius: 18px;
#     padding: 22px 26px;
#     display: flex;
#     align-items: center;
#     gap: 24px;
#     margin-bottom: 18px;
# ">
#     <img src="592_avatar_lr.png" alt="GEOG 592"
#         style="width:110px;height:110px;border-radius:22px;">
#     <div>
#         <div style="
#             font-family: Impact, 'Arial Black', Arial, sans-serif;
#             font-size: 42px;
#             font-weight: 900;
#             letter-spacing: 2px;
#             line-height: 1;
#             color: white;
#         ">GEOG 592</div>
#         <div style="
#             font-family: Arial, Helvetica, sans-serif;
#             font-size: 22px;
#             font-weight: 700;
#             color: #13294B;
#             margin-top: 8px;
#         ">GIS Programming</div>
#         <div style="
#             font-family: Arial, Helvetica, sans-serif;
#             font-size: 16px;
#             color: #13294B;
#             margin-top: 6px;
#         ">Module 3, Day 1: pandas, Objects, and DataFrames</div>
#     </div>
# </div>
#
# # Module 3: Day 1
# ## pandas Fundamentals — From CSV Rows to DataFrames
#
# Today we move from the `csv` module to **pandas**. We will also pause to explain some Python ideas that will become increasingly common: **classes, objects, attributes, methods, and dot notation**.
#
# ### Today you will learn to:
# - explain the difference between Python's standard library and an external package
# - install and import pandas
# - recognize a **class** and an **object**
# - distinguish an **attribute** from a **method**
# - read dot notation such as `df.head()` and `df.shape`
# - read a CSV into a pandas `DataFrame`
# - inspect rows, columns, and data types
# - select columns and rows
# - filter a DataFrame using boolean conditions

# %% [markdown]
# ## From the `csv` Module to pandas
#
# In Module 2 we used `csv.DictReader()`. Each row became a dictionary, and we wrote loops to inspect or clean the file.
#
# pandas gives us a higher-level structure called a **DataFrame**. A DataFrame is designed for working with tabular data.
#
# The same CSV can therefore be represented in two different ways:
#
# ```text
# csv module                     pandas
# -----------                    ------
# list of row dictionaries   ->  DataFrame
# row["LocationName"]        ->  df["LocationName"]
# loop through rows           ->  operations on entire columns
# ```

# %% [markdown]
# ## Installing pandas with `pip`
#
# The `csv` module comes with Python's **standard library**, so it does not need to be installed separately.
#
# `pandas` is an **external package**. If it is not already available in your Python environment, install it with `pip`.
#
# In a Jupyter notebook, the simplest way to do this is:
#
# ```python
# %pip install pandas
# ```
#
# > The `%` symbol is important!
#
# You usually only need to install a package once for a particular Python environment.

# %%
# Run this only if pandas is not installed in the current environment.

# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import pandas
#
# The conventional import is:
#
# ```python
# import pandas as pd
# ```
#
# `pd` is simply a short alias for the pandas module.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %% [markdown]
# ### Practice 1 — Standard library or external package?
#
# For each item below, decide whether it comes with Python or normally needs to be installed separately.
#
# - `csv`
# - `pandas`
#
# Then explain why `import csv` and `import pandas` (or `import pandas as pd`) look similar even though installation is different.

# %% [markdown]
# ## A Short Introduction to Classes and Objects
#
# You do **not** need to learn object-oriented programming today. You just need the basic concepts to understand code such as:
#
# ```python
# df.head()
# df.shape
# df["Data_Value"].mean()
# ```
#
# Here are the definitions.
# - **Class** : a template that defines the kind of data and behavior needed to create an *object*.
# - **Object** :  one actual instance created from a class.  Objects in a class have *attributes* and *methods.*
# - **Attribute** : refers to specific data that belongs to an object.
# - **Method** : refers to a function that belongs to the object; usually all objects of the same class have the same methods (but the methods' behaviour can depent on the specific attributes)

# %% [markdown]
# ### Example of a class
#
# The `Point` class defined below represents a point. It stores two attributes (`x` and `y`) and has two methods.
#
# You are **not expected to be able to write a class definition like this on the assessment**. We are using it only to make dot notation visible.

# %%
class Point:
    def __init__(self, the_x_value, the_y_value):
        self.x = the_x_value ## here we are creating the x attribute
        self.y = the_y_value ## here we are creating the y attribute

    def show_coordinates(self): ## here we are creating the show_coordinates method
        print(self.x, self.y)

    def move(self, dx, dy): ## here we are creating the move method
        self.x = self.x + dx
        self.y = self.y + dy

# %% [markdown]
# The `Point` class has two attributes.
#
# In the next code block, we create two objects from the same `Point` class.

# %%
point_a = Point(100, 200)
point_b = Point(300, 450)

print(point_a.x)
print(point_b.x)
# Out:
# 100
# 300

# %% [markdown]
# In this example:
#
# | Python element | What is it? |
# |---|---|
# | `Point` | a class |
# | `point_a` | an object |
# | `point_b` | another object |
# | `x`, `y` | attributes |
# | `show_coordinates()` | a method |
# | `move()` | another method |

# %% [markdown]
# #### Dot notation
# The **dot** can be read as "something that belongs to this object."

# %%
point_a.show_coordinates()

point_a.move(10, 20)
point_a.show_coordinates()
# Out:
# 100 200
# 110 220

# %% [markdown]
# ### Attribute vs. method
#
# Look at the difference between these two statements.
#
# ```python
# point_a.x
# point_a.show_coordinates()
# ```
# `x` is an **attribute**. It stores information.
# `show_coordinates()` is a **method** that performs an action.
#
# A useful visual clue is that methods are **called with parentheses**.

# %% [markdown]
# ### Practice reading the dot notation
#
# For each expression, identify the object and name/describe what comes after the dot.
#
# ```python
# point_b.y
# point_b.show_coordinates()
# point_b.move(5, -10)
# ```
#
# Which ones are attributes? Which ones are methods?

# %% [markdown]
# The same idea applies to objects that are not GIS features.
# This (for some reason) is one of the most common examples given in programming classes:
#
# ```python
# class Student:
#     def __init__(self, name, score):
#         self.name = name
#         self.score = score
#
#     def passed(self):
#         return self.score >= 70
# ```
#
# Here, `Student` is the class. Each student created from it is an object.
#
# Notice the same pattern:
#
# - `student1.name` → attribute
# - `student1.score` → attribute
# - `student1.passed()` → method
#
# > Reminder: You do **not** need to create classes for this module. The purpose is to understand what Python is doing when you later write code such as `df.head()`, `df.shape`, or `df["Data_Value"].mean()`.

# %%
class Student:
    def __init__(self, name, score):
        self.name = name
        self.score = score

    def passed(self):
        return self.score >= 70

student1 = Student("Ana", 85)

print(student1.name)
print(student1.score)
print(student1.passed())
# Out:
# Ana
# 85
# True

# %% [markdown]
# #### The Dataset
#
# We will continue using the Module 2 file:
#
# ```text
# physical_NC_with_an_error.csv
# ```
#
# It contains North Carolina county-level physical inactivity data and includes an intentional bad record. Keeping the same file lets us focus on how pandas changes the workflow.
#
# Place the CSV in the same folder as this notebook.

# %% [markdown]
# ## Read a CSV into a DataFrame
#
# With pandas, reading the CSV is one line:
#
# ```python
# df = pd.read_csv("physical_NC_with_an_error.csv")
# ```
#
# `pd.read_csv()` returns a **DataFrame object**.

# %%
filename = "physical_NC_with_an_error.csv"
df = pd.read_csv(filename)

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# The important part of the result is `DataFrame`.
#
# So now we can apply the vocabulary from our `Point` example:
#
# ```text
# pandas.DataFrame   -> class
# df                 -> object
# head()             -> method
# shape              -> attribute
# ```

# %% [markdown]
# ## Methods and Attributes of a DataFrame
#
# ### `head()` is a method
#
# A method performs an action using the object.

# %%
df.head(2)
# Out:
#       Year StateAbbr       StateDesc LocationName DataSource  \
# 0  Column1   Column2         Column3      Column4    Column5
# 1     2023        NC  North Carolina    Cleveland      BRFSS
#
#                 Category                                         Measure  \
# 0                Column6                                         Column7
# 1  Health Risk Behaviors  No leisure-time physical activity among adults
#
#   Data_Value_Unit          Data_Value_Type Data_Value  ...  \
# 0         Column8                  Column9   Column10  ...
# 1               %  Age-adjusted prevalence       26.2  ...
#
#   Low_Confidence_Limit High_Confidence_Limit TotalPopulation TotalPop18plus  \
# 0             Column13              Column14        Column15       Column16
# 1                 21.5                  31.5         101,378         78,793
#
#   LocationID CategoryID MeasureId DataValueTypeID  Short_Question_Text  \
# 0   Column17   Column18  Column19        Column20             Column21
# ...

# %% [markdown]
# ### `shape` is an attribute
#
# An attribute stores or reports information about the object.

# %%
df.shape # tells us the dataframe has 101 rows and 22 columns
# Out:
# (101, 22)

# %% [markdown]
# The result has the form:
#
# ```text
# (rows, columns)
# ```
#
# Notice that `shape` does **not** use parentheses.

# %% [markdown]
# ### Practice 3 — Method or attribute?
#
# Classify each of the following using the syntax as a clue.
#
# ```python
# df.head()
# df.tail()
# df.shape
# df.columns
# df.info()
# ```

# %% [markdown]
# ## Inspect the DataFrame
#
# Before analyzing a dataset, inspect its structure.

# %%
df.head(3) #METHOD
# Out:
#       Year StateAbbr       StateDesc LocationName DataSource  \
# 0  Column1   Column2         Column3      Column4    Column5
# 1     2023        NC  North Carolina    Cleveland      BRFSS
# 2     2023        NC  North Carolina        Burke      BRFSS
#
#                 Category                                         Measure  \
# 0                Column6                                         Column7
# 1  Health Risk Behaviors  No leisure-time physical activity among adults
# 2  Health Risk Behaviors  No leisure-time physical activity among adults
#
#   Data_Value_Unit          Data_Value_Type Data_Value  ...  \
# 0         Column8                  Column9   Column10  ...
# 1               %  Age-adjusted prevalence       26.2  ...
# 2               %  Age-adjusted prevalence       26.7  ...
#
#   Low_Confidence_Limit High_Confidence_Limit TotalPopulation TotalPop18plus  \
# 0             Column13              Column14        Column15       Column16
# ...

# %%
df.tail(3) #METHOD
# Out:
#      Year StateAbbr       StateDesc LocationName DataSource  \
# 98   2023        NC  North Carolina      Forsyth      BRFSS
# 99   2023        NC  North Carolina         Wake      BRFSS
# 100  2023        NC  North Carolina        Macon      BRFSS
#
#                   Category                                         Measure  \
# 98   Health Risk Behaviors  No leisure-time physical activity among adults
# 99   Health Risk Behaviors  No leisure-time physical activity among adults
# 100  Health Risk Behaviors  No leisure-time physical activity among adults
#
#     Data_Value_Unit          Data_Value_Type Data_Value  ...  \
# 98                %  Age-adjusted prevalence       24.5  ...
# 99                %  Age-adjusted prevalence       17.9  ...
# 100               %  Age-adjusted prevalence       24.3  ...
#
#     Low_Confidence_Limit High_Confidence_Limit TotalPopulation TotalPop18plus  \
# 98                  20.1                  29.2         392,921        304,926
# ...

# %%
df.columns #attribute
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'LocationName', 'DataSource',
#        'Category', 'Measure', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'TotalPop18plus', 'LocationID', 'CategoryID', 'MeasureId',
#        'DataValueTypeID', 'Short_Question_Text', 'Geolocation'],
#       dtype='str')

# %%
df.dtypes #attribute
# Out:
# Year                          str
# StateAbbr                     str
# StateDesc                     str
# LocationName                  str
# DataSource                    str
# Category                      str
# Measure                       str
# Data_Value_Unit               str
# Data_Value_Type               str
# Data_Value                    str
# Data_Value_Footnote_Symbol    str
# Data_Value_Footnote           str
# Low_Confidence_Limit          str
# High_Confidence_Limit         str
# TotalPopulation               str
# TotalPop18plus                str
# LocationID                    str
# CategoryID                    str
# MeasureId                     str
# DataValueTypeID               str
# Short_Question_Text           str
# Geolocation                   str
# dtype: object

# %% [markdown]
# ### `info()` combines several structural checks
#
# It reports column names, non-null counts, and data types.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        101 non-null    str
#  1   StateAbbr                   101 non-null    str
#  2   StateDesc                   101 non-null    str
#  3   LocationName                101 non-null    str
#  4   DataSource                  101 non-null    str
#  5   Category                    101 non-null    str
#  6   Measure                     101 non-null    str
#  7   Data_Value_Unit             101 non-null    str
#  8   Data_Value_Type             101 non-null    str
#  9   Data_Value                  101 non-null    str
#  10  Data_Value_Footnote_Symbol  1 non-null      str
#  11  Data_Value_Footnote         1 non-null      str
#  12  Low_Confidence_Limit        101 non-null    str
#  13  High_Confidence_Limit       101 non-null    str
# ...

# %% [markdown]
# Why are many columns currently shown as `object` rather than numeric types?
#
# (Look at the first record before answering. Remember that the file contains an intentional error.)

# %% [markdown]
# ## Selecting One Column
#
# Use square brackets and the column name:
#
# ```python
# df["LocationName"]
# ```

# %%
df["LocationName"].head()
# Out:
# 0      Column4
# 1    Cleveland
# 2        Burke
# 3     Alamance
# 4     Beaufort
# Name: LocationName, dtype: str

# %% [markdown]
# A single DataFrame column is usually a pandas **Series object**.

# %%
names = df["LocationName"]
print(type(names))
# Out:
# <class 'pandas.Series'>

# %% [markdown]
# This explains another common chain of notation:
#
# ```python
# df["LocationName"].head()
# ```
#
# Read it from left to right:
#
# 1. `df["LocationName"]` returns a Series object.
# 2. `.head()` calls a method belonging to that Series.

# %% [markdown]
# ## Selecting Multiple Columns
#
# Use a **list of column names** inside the brackets.

# %%
df[["LocationName", "Data_Value", "TotalPopulation"]].head()
# Out:
#   LocationName Data_Value TotalPopulation
# 0      Column4   Column10        Column15
# 1    Cleveland       26.2         101,378
# 2        Burke       26.7          88,338
# 3     Alamance       23.7         179,165
# 4     Beaufort         26          44,481

# %% [markdown]
# Notice the double brackets:
#
# ```python
# df[["LocationName", "Data_Value"]]
# ```
#
# The inner brackets create a list of column names. The outer brackets select those columns from the DataFrame.

# %% [markdown]
# ## Selecting Rows by Position with `iloc`
#
# `iloc` selects rows and columns by integer position.
#
# ```python
# df.iloc[0]
# ```
#
# returns the first row.

# %%
df.iloc[0]
# Out:
# Year                           Column1
# StateAbbr                      Column2
# StateDesc                      Column3
# LocationName                   Column4
# DataSource                     Column5
# Category                       Column6
# Measure                        Column7
# Data_Value_Unit                Column8
# Data_Value_Type                Column9
# Data_Value                    Column10
# Data_Value_Footnote_Symbol    Column11
# Data_Value_Footnote           Column12
# Low_Confidence_Limit          Column13
# High_Confidence_Limit         Column14
# TotalPopulation               Column15
# TotalPop18plus                Column16
# LocationID                    Column17
# CategoryID                    Column18
# MeasureId                     Column19
# DataValueTypeID               Column20
# Short_Question_Text           Column21
# Geolocation                   Column22
# Name: 0, dtype: str

# %%
df.iloc[1:4][["LocationName", "Data_Value"]]
# Out:
#   LocationName Data_Value
# 1    Cleveland       26.2
# 2        Burke       26.7
# 3     Alamance       23.7

# %% [markdown]
# Note from the above can also use `iloc[]` with slice notation to select a range of rows. In this case `1:4` means *include index 1 and everything is between 1 and 4, excluding 4.*

# %% [markdown]
# ## Boolean Comparisons
#
# A comparison against a pandas column produces a Boolean Series.

# %%
df["Year"] == "2023"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 96      True
# 97      True
# 98      True
# 99      True
# 100     True
# Name: Year, Length: 101, dtype: bool

# %% [markdown]
# The result contains `True` or `False` for every row.
#
# We can store this Boolean Series in a variable called a **mask**.

# %%
valid_year = df["Year"] == "2023"
valid_year.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# Name: Year, dtype: bool

# %% [markdown]
# ## Filtering Rows
#
# Use the Boolean mask inside the DataFrame brackets.

# %%
print('length before mask', len(df))
print('length of mask is' ,len(valid_year) ,' and needs to be the same as the length of the df that you want to mask')

clean_year = df[valid_year]

print('length of our new df after using the mask:', len(clean_year))
print('since we had', len(valid_year[valid_year == True]), 'True values')
clean_year.head()
# Out:
# length before mask 101
# length of mask is 101  and needs to be the same as the length of the df that you want to mask
# length of our new df after using the mask: 100
# since we had 100 True values
#    Year StateAbbr       StateDesc LocationName DataSource  \
# 1  2023        NC  North Carolina    Cleveland      BRFSS
# 2  2023        NC  North Carolina        Burke      BRFSS
# 3  2023        NC  North Carolina     Alamance      BRFSS
# 4  2023        NC  North Carolina     Beaufort      BRFSS
# 5  2023        NC  North Carolina     Caldwell      BRFSS
#
#                 Category                                         Measure  \
# 1  Health Risk Behaviors  No leisure-time physical activity among adults
# 2  Health Risk Behaviors  No leisure-time physical activity among adults
# 3  Health Risk Behaviors  No leisure-time physical activity among adults
# 4  Health Risk Behaviors  No leisure-time physical activity among adults
# ...

# %% [markdown]
# Here I am going to mask using information from another column. I am going to mask all the rows that have a county name that starts with an A.
# Think of masking like a fast way of doing a looped `if` statement.

# %%
mask = df["LocationName"].str.startswith("A", na=False)
df2 = df[mask]
df2
# Out:
#     Year StateAbbr       StateDesc LocationName DataSource  \
# 3   2023        NC  North Carolina     Alamance      BRFSS
# 6   2023        NC  North Carolina        Anson      BRFSS
# 12  2023        NC  North Carolina    Alexander      BRFSS
# 14  2023        NC  North Carolina        Avery      BRFSS
# 15  2023        NC  North Carolina         Ashe      BRFSS
# 16  2023        NC  North Carolina    Alleghany      BRFSS
#
#                  Category                                         Measure  \
# 3   Health Risk Behaviors  No leisure-time physical activity among adults
# 6   Health Risk Behaviors  No leisure-time physical activity among adults
# 12  Health Risk Behaviors  No leisure-time physical activity among adults
# 14  Health Risk Behaviors  No leisure-time physical activity among adults
# 15  Health Risk Behaviors  No leisure-time physical activity among adults
# 16  Health Risk Behaviors  No leisure-time physical activity among adults
#
# ...

# %% [markdown]
# One of the most common masking errors is trying to mask a DataFrame using a mask of the wrong dimmension or with different indexing.

# %% [markdown]
# ## Multiple Conditions
#
# Use `&` for AND when combining pandas Boolean conditions. Put each condition in parentheses.

# %%
selected = df[
    (df["Year"] == "2023") &
    (df["StateAbbr"] == "NC")
]

selected[["LocationName", "Data_Value"]].head()
# Out:
#   LocationName Data_Value
# 1    Cleveland       26.2
# 2        Burke       26.7
# 3     Alamance       23.7
# 4     Beaufort         26
# 5     Caldwell       25.5

# %% [markdown]
# Later we will see the same idea again in NumPy and GeoPandas. **Boolean filtering is one of the most transferable ideas in the course.**

# %% [markdown]
# ## Practice — Predict Before Running
#
# What will each expression return: a scalar value, a Series, or a DataFrame?
#
# ```python
# df["LocationName"]
# df[["LocationName", "Data_Value"]]
# df.iloc[0]
# df[df["Year"] == "2023"]
# df.shape
# ```
#
# Also identify which expressions use dot notation.

# %% [markdown]
# ## Preparing for Programming Skills Check #3
#
# You should have a general idea of:
#
# - what a **class** and an **object** are;
# - the difference between an **attribute** and a **method**;
# - reading dot notation such as `df.head()` and `df.shape`;
# - `pd.read_csv()`;
# - DataFrames and Series;
# - `head()`, `shape`, `columns`, and `info()`;
# - selecting one or more columns;
# - `iloc`;
# - Boolean comparisons and using masks;
# - filtering rows with one or more conditions.
#
# You will not be asked to write a class from scratch. The class examples are there to help you understand how pandas objects, attributes, and methods work.
