# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

filename= "data/cleaned_solar_energy_dataset.csv"

df= pd.read_csv(filename)

# %%
df.head()
# Out:
#   Project_ID       Country  Year Technology  Installed_Capacity_MW  \
# 0   RE-00001         India  2023   Solar PV                 658.88
# 1   RE-00007  South Africa  2023   Solar PV                 952.44
# 2   RE-00016         India  2022   Solar PV                1153.20
# 3   RE-00018         India  2011   Solar PV                1336.30
# 4   RE-00022         Spain  2012   Solar PV                 994.63
#
#    Capacity_Factor_Percent  Annual_Generation_MWh  \
# 0                    27.74             1601094.21
# 1                    22.86             1907295.39
# 2                    15.72             1588039.43
# 3                    28.30             3312794.60
# 4                    29.29             2552025.63
#
#    Estimated_CO2_Avoided_tons_per_year
# 0                           1181305.20
# 1                            506213.20
# 2                            426716.16
# 3                           2106957.96
# 4                            669727.44

# %%
df.shape
# Out:
# (336, 8)

# %%
df.columns
# Out:
# Index(['Project_ID', 'Country', 'Year', 'Technology', 'Installed_Capacity_MW',
#        'Capacity_Factor_Percent', 'Annual_Generation_MWh',
#        'Estimated_CO2_Avoided_tons_per_year'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Project_ID                                 str
# Country                                    str
# Year                                     int64
# Technology                                 str
# Installed_Capacity_MW                  float64
# Capacity_Factor_Percent                float64
# Annual_Generation_MWh                  float64
# Estimated_CO2_Avoided_tons_per_year    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Project_ID                           336 non-null    str
#  1   Country                              336 non-null    str
#  2   Year                                 336 non-null    int64
#  3   Technology                           336 non-null    str
#  4   Installed_Capacity_MW                336 non-null    float64
#  5   Capacity_Factor_Percent              336 non-null    float64
#  6   Annual_Generation_MWh                336 non-null    float64
#  7   Estimated_CO2_Avoided_tons_per_year  336 non-null    float64
# dtypes: float64(4), int64(1), str(3)
# memory usage: 21.1 KB

# %% [markdown]
# Filtering with a mask

# %%
less_emissions = df["Estimated_CO2_Avoided_tons_per_year"] > 500000

less_emissions.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Estimated_CO2_Avoided_tons_per_year, dtype: bool

# %%
minimal_co2_emissions = df[less_emissions]

minimal_co2_emissions.head()

print("original df:", df.shape)
print("filtered df:", minimal_co2_emissions.shape)
# Out:
# original df: (336, 8)
# filtered df: (214, 8)
